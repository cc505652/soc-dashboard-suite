# %% [markdown]
# # Alert Scoring & Prioritization
#
# ## Phase
# Phase 4 — Detection Engineering
#
# ## Objective
# Assign a risk score to correlated alerts based on contributing risk factors,
# simulating SOC alert prioritization.

# %%
import pandas as pd
from pathlib import Path

# %%
PROJECT_ROOT = Path(r"D:\soc-dashboard-suite-main\soc-dashboard-suite-main")

INPUT_PATH = PROJECT_ROOT / "data" / "enriched" / "alerts_correlated_deduplicated.csv"
OUTPUT_PATH = PROJECT_ROOT / "data" / "enriched" / "alerts_scored_prioritized.csv"

alerts_df = pd.read_csv(INPUT_PATH, parse_dates=["event_time"])

alerts_df.head()
# Out:
#                  event_time                          sender_email  \
# 0                       NaT                  cramer@cadvision.com
# 1                       NaT           mark.shea@bankofamerica.com
# 2 2000-09-07 02:17:00-07:00                    tmcauliff@isda.org
# 3                       NaT  penn_eric@smtpgate.salkeiz.k12.or.us
# 4                       NaT               matt.hsu@interwoven.com
#
#                 sender_domain  \
# 0               cadvision.com
# 1           bankofamerica.com
# 2                    isda.org
# 3  smtpgate.salkeiz.k12.or.us
# 4              interwoven.com
#
#                                      recipient_email  user_role domain_rarity  \
# 0  john.zufferli@enron.com, demers.nicolas@enron....      admin          rare
# 1  jesus.melendrez@enron.com, john.griffith@enron...  executive          rare
# 2  arothrock@pattonboggs.com, csteffensen@isda.or...  executive          rare
# 3  mark.guzman@enron.com, jones@mca-architects.co...      admin          rare
# 4                                  mleslie@amgen.com      admin          rare
#
#    is_first_seen_day time_behavior  severity  \
# 0              False     off_hours  critical
# 1              False     off_hours  critical
# 2              False     off_hours  critical
# 3              False     off_hours  critical
# 4              False     off_hours  critical
#
#                                         alert_reason  \
# 0  Rare/first-seen external domain + unusual timi...
# 1  Rare/first-seen external domain + unusual timi...
# 2  Rare/first-seen external domain + unusual timi...
# 3  Rare/first-seen external domain + unusual timi...
# 4  Rare/first-seen external domain + unusual timi...
#
#                      detection_id                   source_rule_x  \
# 0  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 1  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 2  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 3  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 4  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
#
#                                        source_rule_y
# 0  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...
# 1  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...
# 2  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...
# 3  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...
# 4  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...

# %%
severity_base = {
    "medium": 40,
    "high": 70,
    "critical": 90
}

alerts_df["risk_score"] = alerts_df["severity"].map(severity_base)

# %%
if "triggered_rules" in alerts_df.columns:
    alerts_df["rule_count"] = alerts_df["triggered_rules"].apply(
        lambda x: len(str(x).split(",")) if pd.notna(x) else 1
    )
else:
    alerts_df["rule_count"] = 1

alerts_df["risk_score"] += alerts_df["rule_count"] * 5

# %%
if "time_behavior" in alerts_df.columns:
    alerts_df.loc[alerts_df["time_behavior"] == "off_hours", "risk_score"] += 5

if "domain_rarity" in alerts_df.columns:
    alerts_df.loc[alerts_df["domain_rarity"] == "rare", "risk_score"] += 5

if "is_first_seen_day" in alerts_df.columns:
    alerts_df.loc[alerts_df["is_first_seen_day"] == True, "risk_score"] += 5

# %%
alerts_df["risk_score"] = alerts_df["risk_score"].clip(upper=100)

# %%
def label_priority(score):
    if score >= 90:
        return "P1"
    elif score >= 75:
        return "P2"
    elif score >= 60:
        return "P3"
    else:
        return "P4"

alerts_df["priority"] = alerts_df["risk_score"].apply(label_priority)

# %%
alerts_df[["severity", "rule_count", "risk_score", "priority"]].head()
# Out:
#    severity  rule_count  risk_score priority
# 0  critical           1         100       P1
# 1  critical           1         100       P1
# 2  critical           1         100       P1
# 3  critical           1         100       P1
# 4  critical           1         100       P1

# %%
alerts_df.to_csv(OUTPUT_PATH, index=False)
print("Saved prioritized alert queue to:", OUTPUT_PATH)
# Out:
# Saved prioritized alert queue to: D:\soc-dashboard-suite-main\soc-dashboard-suite-main\data\enriched\alerts_scored_prioritized.csv

# %%
alerts_df["priority"].value_counts()
# Out:
# priority
# P4    22032
# P2    11513
# P1     1839
# P3     1249
# Name: count, dtype: int64

# %%
alerts_df[alerts_df["priority"] == "P1"].head()
# Out:
#                  event_time                          sender_email  \
# 0                       NaT                  cramer@cadvision.com
# 1                       NaT           mark.shea@bankofamerica.com
# 2 2000-09-07 02:17:00-07:00                    tmcauliff@isda.org
# 3                       NaT  penn_eric@smtpgate.salkeiz.k12.or.us
# 4                       NaT               matt.hsu@interwoven.com
#
#                 sender_domain  \
# 0               cadvision.com
# 1           bankofamerica.com
# 2                    isda.org
# 3  smtpgate.salkeiz.k12.or.us
# 4              interwoven.com
#
#                                      recipient_email  user_role domain_rarity  \
# 0  john.zufferli@enron.com, demers.nicolas@enron....      admin          rare
# 1  jesus.melendrez@enron.com, john.griffith@enron...  executive          rare
# 2  arothrock@pattonboggs.com, csteffensen@isda.or...  executive          rare
# 3  mark.guzman@enron.com, jones@mca-architects.co...      admin          rare
# 4                                  mleslie@amgen.com      admin          rare
#
#    is_first_seen_day time_behavior  severity  \
# 0              False     off_hours  critical
# 1              False     off_hours  critical
# 2              False     off_hours  critical
# 3              False     off_hours  critical
# 4              False     off_hours  critical
#
#                                         alert_reason  \
# 0  Rare/first-seen external domain + unusual timi...
# 1  Rare/first-seen external domain + unusual timi...
# 2  Rare/first-seen external domain + unusual timi...
# 3  Rare/first-seen external domain + unusual timi...
# 4  Rare/first-seen external domain + unusual timi...
#
#                      detection_id                   source_rule_x  \
# 0  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 1  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 2  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 3  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 4  DET_03_MULTI_SIGNAL_EMAIL_RISK  DET_03_MULTI_SIGNAL_EMAIL_RISK
#
#                                        source_rule_y  risk_score  rule_count  \
# 0  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...         100           1
# 1  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...         100           1
# 2  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...         100           1
# 3  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...         100           1
# 4  DET_01_SUSPICIOUS_SENDER_DOMAIN,DET_02_HIGH_RI...         100           1
#
#   priority
# 0       P1
# 1       P1
# 2       P1
# 3       P1
# 4       P1
