# %% [markdown]
# # Detection 03 — Multi-Signal Email Risk
#
# ## Phase
# Phase 4 — Detection Engineering
#
# ## Objective
# Detect high-confidence phishing risk by correlating:
# - Rare or first-seen sender domains
# - Off-hours or unusual timing
# - Privileged recipient roles
#
# This detection reduces false positives by requiring multiple weak signals to align.

# %%
import pandas as pd
from pathlib import Path

# %%
PROJECT_ROOT = Path(r"D:\soc-dashboard-suite-main\soc-dashboard-suite-main")

INPUT_PATH = PROJECT_ROOT / "data" / "enriched" / "email_with_temporal_context.csv"
ALERT_OUTPUT_PATH = PROJECT_ROOT / "data" / "enriched" / "alerts_multi_signal_email_risk.csv"

email_df = pd.read_csv(INPUT_PATH, parse_dates=["event_time"])

# %%
email_df["external_sender"] = email_df["sender_domain"] != email_df["recipient_domain"]

# %%
domain_risk = (
    (email_df["domain_rarity"] == "rare") |
    (email_df["is_first_seen_day"] == True)
)

time_risk = email_df["time_behavior"].isin(["off_hours", "unusual_hour"])
identity_risk = email_df["user_role"].isin(["admin", "executive"])
external_risk = email_df["external_sender"] == True

alerts_df = email_df[domain_risk & time_risk & identity_risk & external_risk].copy()

len(alerts_df)
# Out:
# 3929

# %%
alerts_df["detection_id"] = "DET_03_MULTI_SIGNAL_EMAIL_RISK"
alerts_df["severity"] = "critical"

alerts_df["alert_reason"] = (
    "Rare/first-seen external domain + unusual timing + privileged recipient"
)

# %%
alert_fields = [
    "event_time",
    "sender_email",
    "sender_domain",
    "recipient_email",
    "user_role",
    "domain_rarity",
    "is_first_seen_day",
    "time_behavior",
    "severity",
    "alert_reason",
    "detection_id"
]

alerts_df = alerts_df[alert_fields]
alerts_df.head()
# Out:
#      event_time      sender_email sender_domain  \
# 612         NaT  aod@newsdata.com  newsdata.com
# 1434        NaT  aod@newsdata.com  newsdata.com
# 2014        NaT  aod@newsdata.com  newsdata.com
# 3912        NaT   info@amazon.com    amazon.com
# 3948        NaT   msagel@home.com      home.com
#
#                                    recipient_email  user_role domain_rarity  \
# 612   western.price.survey.contacts@ren-6.cais.net      admin          rare
# 1434  western.price.survey.contacts@ren-6.cais.net      admin          rare
# 2014  western.price.survey.contacts@ren-6.cais.net      admin          rare
# 3912                             jarnold@enron.com  executive          rare
# 3948                             jarnold@enron.com  executive          rare
#
#       is_first_seen_day time_behavior  severity  \
# 612               False     off_hours  critical
# 1434              False     off_hours  critical
# 2014              False     off_hours  critical
# 3912              False     off_hours  critical
# 3948              False     off_hours  critical
#
#                                            alert_reason  \
# 612   Rare/first-seen external domain + unusual timi...
# 1434  Rare/first-seen external domain + unusual timi...
# 2014  Rare/first-seen external domain + unusual timi...
# 3912  Rare/first-seen external domain + unusual timi...
# 3948  Rare/first-seen external domain + unusual timi...
#
#                         detection_id
# 612   DET_03_MULTI_SIGNAL_EMAIL_RISK
# 1434  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 2014  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 3912  DET_03_MULTI_SIGNAL_EMAIL_RISK
# 3948  DET_03_MULTI_SIGNAL_EMAIL_RISK

# %%
alerts_df.to_csv(ALERT_OUTPUT_PATH, index=False)
print("Saved alerts to:", ALERT_OUTPUT_PATH)
# Out:
# Saved alerts to: D:\soc-dashboard-suite-main\soc-dashboard-suite-main\data\enriched\alerts_multi_signal_email_risk.csv

# %%
len(alerts_df) / len(email_df)
# Out:
# 0.007928500223991735
