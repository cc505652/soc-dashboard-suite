# %% [markdown]
# # Temporal Context & Time-Based Baselining
#
# ## Phase
# Phase 3 — Context & Baselining
#
# ## Objective
# Introduce time-based behavioral context into email telemetry by:
# - Identifying business vs off-hours activity
# - Modeling typical active hours per user
#
# This enables detection logic to later reason about abnormal timing.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
PROJECT_ROOT = Path(r"D:\soc-dashboard-suite-main\soc-dashboard-suite-main")

INPUT_PATH = PROJECT_ROOT / "data" / "enriched" / "email_with_identity_context.csv"
OUTPUT_PATH = PROJECT_ROOT / "data" / "enriched" / "email_with_temporal_context.csv"

email_df = pd.read_csv(INPUT_PATH, parse_dates=["event_time"])

email_df.head()
# Out:
#                  event_time             sender_email sender_domain  \
# 0 2001-05-14 16:39:00-07:00  phillip.allen@enron.com     enron.com
# 1 2001-05-04 13:51:00-07:00  phillip.allen@enron.com     enron.com
# 2 2000-10-18 03:00:00-07:00  phillip.allen@enron.com     enron.com
# 3 2000-10-23 06:13:00-07:00  phillip.allen@enron.com     enron.com
# 4 2000-08-31 05:07:00-07:00  phillip.allen@enron.com     enron.com
#
#            recipient_email recipient_domain    subject  \
# 0     tim.belden@enron.com        enron.com        NaN
# 1  john.lavorato@enron.com        enron.com        Re:
# 2   leah.arsdall@enron.com        enron.com   Re: test
# 3    randall.gay@enron.com        enron.com        NaN
# 4     greg.piper@enron.com        enron.com  Re: Hello
#
#                  message_id   event_type                 ingested_at  \
# 0     allen-p/_sent_mail/1.  email_event  2026-01-31 05:05:10.685001
# 1    allen-p/_sent_mail/10.  email_event  2026-01-31 05:05:10.685001
# 2   allen-p/_sent_mail/100.  email_event  2026-01-31 05:05:10.685001
# 3  allen-p/_sent_mail/1000.  email_event  2026-01-31 05:05:10.685001
# 4  allen-p/_sent_mail/1001.  email_event  2026-01-31 05:05:10.685001
#
#   domain_rarity  email_count_x          first_seen_time_x  \
# 0        common       409084.0  1979-12-31 16:00:00-08:00
# 1        common       409084.0  1979-12-31 16:00:00-08:00
# 2        common       409084.0  1979-12-31 16:00:00-08:00
# 3        common       409084.0  1979-12-31 16:00:00-08:00
# 4        common       409084.0  1979-12-31 16:00:00-08:00
#
#            first_seen_time_y            first_seen_time  is_first_seen_day  \
# 0  1998-05-27 08:31:00-07:00  1998-05-27 08:31:00-07:00              False
# 1  1998-05-27 08:31:00-07:00  1998-05-27 08:31:00-07:00              False
# 2  1998-05-27 08:31:00-07:00  1998-05-27 08:31:00-07:00              False
# 3  1998-05-27 08:31:00-07:00  1998-05-27 08:31:00-07:00              False
# 4  1998-05-27 08:31:00-07:00  1998-05-27 08:31:00-07:00              False
#
#             recipient_user user_role  email_count_y  email_count  \
# 0     tim.belden@enron.com    normal            397          397
# 1  john.lavorato@enron.com    normal           1481         1481
# 2   leah.arsdall@enron.com    normal             11           11
# 3    randall.gay@enron.com    normal             48           48
# 4     greg.piper@enron.com    normal            186          186
#
#      user_volume_band
# 0     low_volume_user
# 1  medium_volume_user
# 2     low_volume_user
# 3     low_volume_user
# 4     low_volume_user

# %%
email_df["hour"] = email_df["event_time"].dt.hour
email_df["day_of_week"] = email_df["event_time"].dt.dayofweek  # Monday=0

# %%
email_df["is_business_hours"] = (
    (email_df["hour"] >= 8) &
    (email_df["hour"] <= 18) &
    (email_df["day_of_week"] < 5)
)

# %%
user_hour_mode = (
    email_df.groupby("recipient_user")["hour"]
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
    .reset_index()
)

user_hour_mode.columns = ["recipient_user", "typical_active_hour"]

email_df = email_df.merge(user_hour_mode, on="recipient_user", how="left")

# %%
email_df["hour_deviation"] = abs(email_df["hour"] - email_df["typical_active_hour"])

# %%
def classify_time_behavior(row):
    if not row["is_business_hours"]:
        return "off_hours"
    elif row["hour_deviation"] > 4:
        return "unusual_hour"
    else:
        return "normal_time"

email_df["time_behavior"] = email_df.apply(classify_time_behavior, axis=1)

# %%
email_df.to_csv(OUTPUT_PATH, index=False)
print("Saved temporal-enriched dataset to:", OUTPUT_PATH)
# Out:
# Saved temporal-enriched dataset to: D:\soc-dashboard-suite-main\soc-dashboard-suite-main\data\enriched\email_with_temporal_context.csv

# %%
email_df["time_behavior"].value_counts()
# Out:
# time_behavior
# off_hours       377763
# normal_time      78630
# unusual_hour     39161
# Name: count, dtype: int64
